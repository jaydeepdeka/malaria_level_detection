# %%
import cv2
import os
import numpy as np
import shutil
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# For data Augmentation
import random
from scipy import ndarray
import skimage as sk
from skimage import transform
from skimage import util

# %% [markdown]
# Set the dataset path the cropped images

# %%
dataset_path = r"E:\Class_Notes_Sem2\ADM\Project\malaria-bounding-boxes\malaria\Cropped_images"
os.chdir(dataset_path)

# %% [markdown]
# A dataframe to store the current path of the datasets and their sizes

# %%
df = pd.DataFrame(columns = ['Path', 'Size'])
for folders in os.listdir(dataset_path):
    df.loc[folders.replace(' ','_')] = [os.path.join(dataset_path, folders)]+[len(os.listdir(folders))]

# %%
df
# ax = df.plot.bar(y='Size', rot=0)
# Out:
#                                                              Path   Size
# difficult       E:\Class_Notes_Sem2\ADM\Project\malaria-boundi...    446
# gametocyte      E:\Class_Notes_Sem2\ADM\Project\malaria-boundi...    156
# red_blood_cell  E:\Class_Notes_Sem2\ADM\Project\malaria-boundi...  77573
# ring            E:\Class_Notes_Sem2\ADM\Project\malaria-boundi...    521
# schizont        E:\Class_Notes_Sem2\ADM\Project\malaria-boundi...    190
# trophozoite     E:\Class_Notes_Sem2\ADM\Project\malaria-boundi...   1584

# %%
plt.bar(df.index.values, height=df['Size'])
plt.show()

# %% [markdown]
# A threshold value of 500 has been cosidered for upsample and downsample.

# %%
classes_to_downsample = df[df['Size']>500].index.values
classes_to_upsample = df[df['Size']<=500].index.values
print("Classes going to be downsampled {} and classes going to upsampled are {}".format(classes_to_downsample, classes_to_upsample))
# Out:
# Classes going to be downsampled ['red_blood_cell' 'ring' 'trophozoite'] and classes going to upsampled are ['difficult' 'gametocyte' 'schizont']

# %%
try:
    os.mkdir("../Processed_Images")
except Exception as e:
        print(e)
for classes in df.index.values:
    try:
        os.mkdir("../Processed_Images/{}".format(classes))
    except Exception as e:
        print(e)

# %% [markdown]
# Sample 500 images from each of the categories and move it to the dataset

# %%
for classes in classes_to_downsample:
    # Getting the file names
    files = os.listdir(df.loc[classes]['Path'])
    # Random Sampling the file indexes
    sample_idx = np.random.choice(len(files), size=500, replace=False)
    for index in sample_idx:
        try:
            shutil.copy(os.path.join(df.loc[classes]['Path'], files[index]), "../Processed_Images/{}".format(classes))
        except Exception as e:
            print("Error occured as {}".format(e))

# %% [markdown]
# Move the images to upsample

# %%
for classes in classes_to_upsample:
    # Getting the file names
    files = os.listdir(df.loc[classes]['Path'])
#     # Random Sampling the file indexes
    sample_idx = np.random.choice(len(files), size=500, replace=True)
    for file in files:
        try:
            shutil.copy(os.path.join(df.loc[classes]['Path'], file), "../Processed_Images/{}/".format(classes))
        except Exception as e:
            print("Error occured as {}".format(e))

# %%
df2 = pd.DataFrame(columns = ['Size'])
for folders in os.listdir("../Processed_Images"):
    df2.loc[folders.replace(' ','_')] = [len(os.listdir(os.path.join("../Processed_Images", folders)))]

# %%
plt.bar(df2.index.values, height=df2['Size'])
plt.show()

# %%
os.mkdir("../Processed_Images/train")
os.mkdir("../Processed_Images/test")
for categories in df.index.values:
    try:
        os.mkdir("../Processed_Images/train/{}".format(categories))
        os.mkdir("../Processed_Images/test/{}".format(categories))
    except Exception as e:
            print("Error occured as {}".format(e))
for folders in os.listdir("../Processed_Images"):
    if folders in ['test', 'train']:
        continue
    files = os.listdir(os.path.join("../Processed_Images", folders))
#     sample_idx = np.random.choice(len(files), size=int(len(files)*.90), replace=False)
    for file in files[:int(len(files)*.90)]:
        try:
            shutil.copy(os.path.join("../Processed_Images/{}".format(folders), file), 
                        "../Processed_Images/train/{}".format(folders))
        except Exception as e:
            print("Error occured as {}".format(e))
    for file in files[int(len(files)*.90):]:
        try:
            shutil.copy(os.path.join("../Processed_Images/{}".format(folders), file), 
                        "../Processed_Images/test/{}".format(folders))
        except Exception as e:
            print("Error occured as {}".format(e))

# %%
def random_rotation(image_array: ndarray):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree)

def random_noise(image_array: ndarray):
    # add random noise to the image
    return sk.util.random_noise(image_array)

def horizontal_flip(image_array: ndarray):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

# %%
import random
import os

# our folder path containing some images
folder_path = r'E:\Class_Notes_Sem2\ADM\Project\malaria-bounding-boxes\malaria\Extracted_images\difficult'
# the number of file to generate
num_files_desired = 1000

# loop on all files of the folder and build a list of files paths
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

num_generated_files = 0
while num_generated_files <= num_files_desired:
    # random image from the folder
    image_path = random.choice(images)
    # read image as an two dimensional array of pixels
    image_to_transform = sk.io.imread(image_path)
    available_transformations = {
        'rotate': random_rotation,
        'noise': random_noise,
        'horizontal_flip': horizontal_flip
    }

    # random num of transformations to apply
    num_transformations_to_apply = random.randint(1, len(available_transformations))

    num_transformations = 0
    transformed_image = None
    while num_transformations <= num_transformations_to_apply:
        # choose a random transformation to apply for a single image
        key = random.choice(list(available_transformations))
        transformed_image = available_transformations[key](image_to_transform)
        num_transformations += 1
        new_file_path = '%s/augmented_image_%s.jpg' % (folder_path, num_generated_files)

        # write image to the disk
        sk.io.imsave(new_file_path, transformed_image)
    num_generated_files += 1
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
